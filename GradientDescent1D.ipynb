# %% [markdown]
# <a href="https://colab.research.google.com/github/avishek-astra/Deep-Learning/blob/main/GradientDescent1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# make equation look nicer
from IPython.display import display,set_matplotlib_formats
set_matplotlib_formats('svg')

# %%
#gradient descent in 1D
def fx(x):
  return np.sin(x)*np.exp(-x**2*0.05)
#derivative function
def deriv(x):
  return np.exp(-0.05 * x**2) * (np.cos(x) - 0.1 * x * np.sin(x))

# %%
#plot the function and its derivative
#define a range for x
x=np.linspace(-2*(np.pi),2*(np.pi),401)
#plotting
plt.plot(x,fx(x),x,deriv(x))
plt.grid()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(['f(x)','df'])
plt.show()

# %%
#random starting point
localmin=np.random.choice(x,1)
print(localmin)

#learning parameters-
learning_rate=.01
training_epochs=1000
#run through training
for i in range(training_epochs):
  grad=deriv(localmin)
  localmin=localmin-learning_rate*grad
localmin
# Out:
# [-3.01592895]
# array([-1.42900243])

# %%
#plot the result
plt.plot(x,fx(x),x,deriv(x),'--')
plt.plot(localmin,deriv(localmin),'ro')
plt.plot(localmin,fx(localmin),'ro')
plt.grid()
plt.xlim(x[[0,-1]])
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(['y','dy'])
plt.title(f'Emperical local minima is :{localmin[0]:.5f}')
plt.show()

# %%
#store the model parameters and outputs on each iteration

# %%
#random starting point
localmin=np.random.choice(x,1)
#learning parameters
learning_rate=.01
training_epochs=100
#setting threshold
#run through traing and store all the results
modelparams=np.zeros((training_epochs,2))
for i in range(training_epochs):
  grad=deriv(localmin)
  localmin=localmin-learning_rate*grad
  modelparams[i,:]=localmin.item(),grad.item()
print(localmin)
# Out:
# [4.98457365]

# %%
#plot the gradient over iterations
fig,ax=plt.subplots(1,2,figsize=(10,5))
for i in range(2):
  ax[i].plot(modelparams[:,i],'o-')
  ax[i].set_xlabel('iteration')

ax[0].set_title(f'final estimated minimum:{localmin[0]:0.5f}')
ax[0].set_title(f'final estimated minimum:{localmin[0]:0.5f}')

ax[0].set_ylabel('local minimum')
ax[1].set_ylabel('Derivative')
# Out:
# Text(0, 0.5, 'Derivative')

# %% [markdown]
# ADDITIONAL EXPLORATIONS

# %%
##1)Most often in DL, the model trains for a set of iteration, which is what we do here. But there are other ways of defining how long the training lasts
#Modify the code so that training ends when the derivative is maller than some threshold, e.g.,0.1 Make sure your code is robust for negative derivative.
#2)Does this change to the code produce a more accurate result? What if you
# change the stopping threshold?
#3) Can you think of any potential problems that might arise when the stopping criteria is based on the derivative
# instead of a specified number of training epochs?
#

# %%
#random starting point
localmin=np.random.choice(x,1)
#learning parameters
learning_rate=.01
training_epochs=50
#setting threshold
threshold=0.01
#run through traing and store all the results
modelparams=np.zeros((training_epochs,2))
for i in range(training_epochs):
  grad=deriv(localmin)
  localmin=localmin-learning_rate*grad
  modelparams[i,:]=localmin.item(),grad.item()
  if np.abs(grad)<threshold:
    break
print(localmin)
# Out:
# [0.43028134]

# %%
#plot the gradient over iterations
fig,ax=plt.subplots(1,2,figsize=(10,5))
for i in range(2):
  ax[i].plot(modelparams[:,i],'o-')
  ax[i].set_xlabel('iteration')

ax[0].set_title(f'final estimated minimum:{localmin[0]:0.5f}')
ax[0].set_title(f'final estimated minimum:{localmin[0]:0.5f}')

ax[0].set_ylabel('local minimum')
ax[1].set_ylabel('Derivative')
# Out:
# Text(0, 0.5, 'Derivative')

# %% [markdown]
# Code Challenges
